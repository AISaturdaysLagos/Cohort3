# %% [markdown]
# ## Linear Regression
# #### Univariant Linear Regression, from scratch.

# %% [markdown]
# #### AI Saturday Lagos Begineers Class (Instructors: Tejumade Afonja, Kenechi Dukor, Ifeanyi Igwegbe George)
# This exercise is adopted from [Andrew Ng Machine Learning Course](https://www.coursera.org/learn/machine-learning)

# %% [markdown]
# NOTE: You will notice slight modification on the codes which makes it a bit different from what we practiced in class. Please do not get confused.
#
# The whole concept remains the same, i only made the codes shorter.

# %%
# Libraries required for this practice 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading Data

# %% [markdown]
# The data we will be using is a .txt file which contains a list of population for different cities and their corresponding profit.
#
# The values on the first column contains the population of the cities and the values of the second column contains the corresponding profits, in 10,000's, seperated by a comma..
#
# The goal of this exercise is to use linear regression and the optimization technique to generate a model that will precitreasonable estimate of a city's profit when it is supplied the city's population.

# %%
# Using pandas to view the data
data = pd.read_csv("ex1data1.txt", sep=',', header = None)
data.columns=["Population of city in 10,000","Profit in $10,000"]

# %%
# this will show the first five data in the dataframe
data.head()
# Out:
#    Population of city in 10,000  Profit in $10,000
# 0                        6.1101            17.5920
# 1                        5.5277             9.1302
# 2                        8.5186            13.6620
# 3                        7.0032            11.8540
# 4                        5.8598             6.8233

# %%
# Lets convert values of the pandas dataframe into a numpy array
data = data.values

# %% [markdown]
# You can also convert the data in to a numpy array without needing to go through pandas. Use the code below
#
# `data = np.loadtxt("ex1data1.txt", delimiter=',')`

# %%
print(data.shape)
# Out:
# (97, 2)

# %% [markdown]
# We have 97 training examples and one independent variable `x` on the first column and one dependent variable `y` on the second column
#
# **Recall:**
# - Our untrained model is given by: ![title](img/model.gif)
#
# - Which you can also be written as ![title](img/model2.gif)
#
# where:
# - `y` is the ground truth or output
# - `x` is the input values
# - `theta` is the weight or parameters that needs to learn

# %% [markdown]
# Beacuse the coefficient of `theta` is `x` and `1`, we want to create a `97 x 2` matrix that contains the input values on the first column and ones in the second column

# %%
x = np.c_[data[:,0], np.ones(data.shape[0])]

# %% [markdown]
# Similarly, we want to create a row vector with a dimension of `97 x 1` for all the output values in our dataset

# %%
y = np.c_[data[:,1]]

# %% [markdown]
# ### Data Visualization

# %%
# Lets plot the data to see how they correlate.
plt.scatter(x[:,0], y, s=32, marker='o')
plt.xlabel("Population of city in 10,000")
plt.ylabel("Profit in $10,000")
# Out:
# Text(0, 0.5, 'Profit in $10,000')

# %% [markdown]
# Notice that there is a positive correlation between the two data. This means that we can develop a model that will be able to make reasonable predictions

# %% [markdown]
# ### Training

# %% [markdown]
# Recall from the class, the process to training a linear regression model is as follow.
#
# We want to find the appropriate value of `theta` that will give us a good estimate of a city's profit if lthe city's population is supplied.
#
# To do this,
# - We want to start with a random value of `theta` to generate a hypothesis
# ![title](img/model3.gif)
#
# - Then continually correct values of `theta` until the deviation of the hypothesis/prediction `h` from the ground-truth `y` is greatly reduced
#
# **Note:**
# - Matrix multiplication was utilized for the calculation?.

# %%
def train(x, y):
    iteration = 2500
    # For this practice are initiallizing are theta with values of zero.
    theta = [[0],[0]]
    # Here, want to save our cost function or loss or square error, 
    # so that we can have an idea of how the deviation of the hypothesis from the ground thruth reduces
    cost_function = np.zeros(iteration)
    
    for i in range(iteration):
        # Step 1: we make a prediction using the random weights (theta) that we initialized
        # @ is a fancy way do performing dot products
        h = x @ theta
        # Step 2: We take a step to correct the weights (theta) to that the next predicion will be better
        theta = update_weight(h, theta, x)
        # Step 3: We measure the deviation or error
        cost_function[i] = cost(x, theta)

        print("The cost function is ", cost_function[i])
        
    return theta, cost_function

# %% [markdown]
# But how do we check the error like we defined above?
#
# Remember the error formular (cost function)?
# ![title](img/model44.gif)
#
# where:
# - `m` is the number of training example
# - `x` is the input data
# - `h` is the hypothesis
# - `y` is the prediction
#
# The equation tries to find the square error between the ground truth and the prediction.

# %%
def cost(x, theta):
    m = x[:,0].size
    h = x @ theta
    return (1/2*m) * np.sum(np.square(h - y))

# %% [markdown]
# Now that we are able to get a sense of the error, how do we update how weight (theta) such that is predicts better?
#
# Like we discussed in class, gradient descent algorithim will be used for this purpose.
#
# The general formular for gradient is given below:
# ![title](img/model6.gif)
# which can be differentiated to give:
# ![title](img/model5.gif)
# where
# - alpha is the learning rate
#
# ie: we continually update the weight(theta) by taking steps(alpha) for the derived gradient of the error until we have sufficiently minimized theta.

# %%
def update_weight(h, theta, x):
    m = x[:,0].size
    alpha = 0.01
    theta = theta - alpha * (1/m * (x.T @ (h - y)))
    return theta

# %% [markdown]
# Now, lets pass in our data and train.

# %%
theta, cost_values = train(x, y)
# Out:
# The cost function is  63390.22508396189
# The cost function is  55810.36388700404
# The cost function is  55523.96463892878
# The cost function is  55468.205769853674
# The cost function is  55419.90331979097
# The cost function is  55372.00412679627
# The cost function is  55324.28470894376
# The cost function is  55276.73740262106
# The cost function is  55229.36136618629
# The cost function is  55182.15597572936
# The cost function is  55135.120616371896
# The cost function is  55088.25467566468
# The cost function is  55041.55754337132
# The cost function is  54995.02861145362
# The cost function is  54948.667274063555
# The cost function is  54902.472927535295
# The cost function is  54856.4449703774
# The cost function is  54810.582803264966
# The cost function is  54764.8858290318
# The cost function is  54719.353452662675
# The cost function is  54673.98508128563
# The cost function is  54628.780124164085
# The cost function is  54583.73799268937
# The cost function is  54538.85810037289
# The cost function is  54494.13986283856
# The cost function is  54449.58269781518
# The cost function is  54405.186025128845
# The cost function is  54360.94926669545
# The cost function is  54316.87184651306
# The cost function is  54272.9531906545
# The cost function is  54229.19272725985
# The cost function is  54185.589886528964
# The cost function is  54142.144100714104
# The cost function is  54098.85480411255
# The cost function is  54055.721433059145
# The cost function is  54012.74342591911
# The cost function is  53969.92022308055
# The cost function is  53927.251266947336
# The cost function is  53884.736001931735
# The cost function is  53842.37387444719
# The cost function is  53800.164332901164
# The cost function is  53758.10682768792
# The cost function is  53716.20081118136
# The cost function is  53674.445737727896
# The cost function is  53632.84106363936
# The cost function is  53591.38624718593
# The cost function is  53550.08074858903
# The cost function is  53508.924030014394
# The cost function is  53467.91555556494
# The cost function is  53427.054791273884
# The cost function is  53386.34120509777
# The cost function is  53345.77426690954
# The cost function is  53305.35344849154
# The cost function is  53265.07822352888
# The cost function is  53224.948067602265
# The cost function is  53184.9624581814
# The cost function is  53145.12087461817
# The cost function is  53105.4227981397
# The cost function is  53065.867711841776
# The cost function is  53026.45510068199
# The cost function is  52987.18445147316
# The cost function is  52948.0552528765
# The cost function is  52909.06699539505
# The cost function is  52870.2191713671
# The cost function is  52831.51127495942
# The cost function is  52792.94280216082
# The cost function is  52754.51325077546
# The cost function is  52716.22212041645
# The cost function is  52678.06891249927
# The cost function is  52640.05313023522
# The cost function is  52602.174278625025
# The cost function is  52564.43186445237
# The cost function is  52526.82539627749
# The cost function is  52489.35438443073
# The cost function is  52452.01834100625
# The cost function is  52414.81677985554
# The cost function is  52377.74921658122
# The cost function is  52340.8151685307
# The cost function is  52304.0141547898
# The cost function is  52267.34569617666
# The cost function is  52230.80931523535
# The cost function is  52194.40453622969
# The cost function is  52158.13088513712
# The cost function is  52121.98788964248
# The cost function is  52085.97507913183
# The cost function is  52050.09198468636
# The cost function is  52014.33813907632
# The cost function is  51978.71307675484
# The cost function is  51943.21633385195
# The cost function is  51907.84744816852
# The cost function is  51872.605959170214
# The cost function is  51837.49140798152
# The cost function is  51802.50333737976
# The cost function is  51767.641291789194
# The cost function is  51732.904817275
# The cost function is  51698.29346153739
# The cost function is  51663.80677390576
# The cost function is  51629.44430533276
# The cost function is  51595.20560838856
# The cost function is  51561.09023725487
# The cost function is  51527.09774771922
# The cost function is  51493.2276971692
# The cost function is  51459.479644586674
# The cost function is  51425.85315054197
# The cost function is  51392.34777718825
# The cost function is  51358.96308825581
# The cost function is  51325.69864904627
# The cost function is  51292.554026427126
# The cost function is  51259.52878882591
# The cost function is  51226.62250622468
# The cost function is  51193.83475015439
# The cost function is  51161.165093689306
# The cost function is  51128.61311144147
# The cost function is  51096.17837955514
# The cost function is  51063.86047570129
# The cost function is  51031.6589790721
# The cost function is  50999.573470375435
# The cost function is  50967.60353182946
# The cost function is  50935.7487471572
# The cost function is  50904.008701581006
# The cost function is  50872.38298181728
# The cost function is  50840.87117607106
# The cost function is  50809.47287403062
# The cost function is  50778.18766686216
# The cost function is  50747.01514720449
# The cost function is  50715.95490916368
# The cost function is  50685.006548307836
# The cost function is  50654.169661661785
# The cost function is  50623.44384770188
# The cost function is  50592.82870635069
# The cost function is  50562.32383897188
# The cost function is  50531.92884836496
# The cost function is  50501.643338760136
# The cost function is  50471.466915813166
# The cost function is  50441.39918660018
# The cost function is  50411.43975961265
# The cost function is  50381.58824475221
# The cost function is  50351.84425332559
# The cost function is  50322.20739803956
# The cost function is  50292.67729299598
# The cost function is  50263.253553686605
# The cost function is  50233.93579698821
# The cost function is  50204.72364115756
# The cost function is  50175.61670582637
# The cost function is  50146.61461199653
# The cost function is  50117.71698203497
# The cost function is  50088.923439668884
# The cost function is  50060.23360998075
# The cost function is  50031.64711940348
# The cost function is  50003.16359571559
# The cost function is  49974.78266803624
# The cost function is  49946.50396682057
# The cost function is  49918.32712385473
# The cost function is  49890.2517722512
# The cost function is  49862.27754644395
# The cost function is  49834.404082183675
# The cost function is  49806.63101653312
# The cost function is  49778.95798786229
# The cost function is  49751.38463584374
# The cost function is  49723.910601447926
# The cost function is  49696.5355269385
# The cost function is  49669.25905586768
# The cost function is  49642.080833071544
# The cost function is  49615.000504665506
# The cost function is  49588.017718039584
# The cost function is  49561.132121853945
# The cost function is  49534.34336603423
# The cost function is  49507.65110176701
# The cost function is  49481.05498149531
# The cost function is  49454.55465891398
# The cost function is  49428.149788965275
# The cost function is  49401.84002783435
# The cost function is  49375.62503294468
# The cost function is  49349.50446295376
# The cost function is  49323.47797774857
# The cost function is  49297.5452384411
# The cost function is  49271.70590736408
# The cost function is  49245.959648066426
# The cost function is  49220.306125308976
# The cost function is  49194.74500506006
# The cost function is  49169.27595449116
# The cost function is  49143.89864197262
# The cost function is  49118.61273706927
# The cost function is  49093.417910536155
# The cost function is  49068.31383431424
# The cost function is  49043.30018152614
# The cost function is  49018.37662647189
# The cost function is  48993.5428446246
# The cost function is  48968.7985126264
# The cost function is  48944.143308284096
# The cost function is  48919.576910564996
# The cost function is  48895.098999592774
# The cost function is  48870.70925664328
# The cost function is  48846.40736414037
# The cost function is  48822.19300565182
# The cost function is  48798.06586588517
# The cost function is  48774.02563068359
# The cost function is  48750.07198702185
# The cost function is  48726.204623002275
# The cost function is  48702.42322785051
# The cost function is  48678.72749191168
# The cost function is  48655.117106646256
# The cost function is  48631.59176462601
# The cost function is  48608.15115953011
# The cost function is  48584.794986141016
# The cost function is  48561.52294034062
# The cost function is  48538.334719106184
# The cost function is  48515.23002050645
# The cost function is  48492.20854369772
# The cost function is  48469.26998891993
# The cost function is  48446.41405749269
# The cost function is  48423.640451811414
# The cost function is  48400.948875343594
# The cost function is  48378.339032624695
# The cost function is  48355.81062925447
# The cost function is  48333.363371893094
# The cost function is  48310.99696825732
# The cost function is  48288.711127116694
# The cost function is  48266.50555828977
# The cost function is  48244.3799726403
# The cost function is  48222.33408207347
# The cost function is  48200.36759953224
# The cost function is  48178.48023899345
# The cost function is  48156.67171546421
# The cost function is  48134.94174497818
# The cost function is  48113.29004459183
# The cost function is  48091.71633238077
# The cost function is  48070.22032743609
# The cost function is  48048.80174986071
# The cost function is  48027.46032076571
# The cost function is  48006.19576226671
# The cost function is  47985.00779748026
# The cost function is  47963.89615052025
# The cost function is  47942.860546494245
# The cost function is  47921.9007115
# The cost function is  47901.01637262183
# The cost function is  47880.20725792708
# The cost function is  47859.47309646259
# The cost function is  47838.813618251144
# The cost function is  47818.22855428798
# The cost function is  47797.71763653727
# The cost function is  47777.28059792862
# The cost function is  47756.91717235364
# The cost function is  47736.627094662435
# The cost function is  47716.41010066014
# The cost function is  47696.26592710354
# The cost function is  47676.19431169758
# The cost function is  47656.19499309202
# The cost function is  47636.26771087792
# The cost function is  47616.41220558436
# The cost function is  47596.62821867504
# The cost function is  47576.91549254485
# The cost function is  47557.27377051658
# The cost function is  47537.70279683755
# The cost function is  47518.202316676274
# The cost function is  47498.772076119196
# The cost function is  47479.4118221673
# The cost function is  47460.12130273288
# The cost function is  47440.90026663623
# The cost function is  47421.74846360236
# The cost function is  47402.66564425778
# The cost function is  47383.65156012725
# The cost function is  47364.70596363046
# The cost function is  47345.82860807891
# The cost function is  47327.01924767268
# The cost function is  47308.27763749714
# The cost function is  47289.60353351991
# The cost function is  47270.99669258753
# The cost function is  47252.4568724224
# The cost function is  47233.98383161961
# The cost function is  47215.577329643704
# The cost function is  47197.237126825705
# The cost function is  47178.96298435986
# The cost function is  47160.75466430059
# The cost function is  47142.6119295594
# The cost function is  47124.53454390175
# The cost function is  47106.522271943984
# The cost function is  47088.57487915034
# The cost function is  47070.692131829834
# The cost function is  47052.87379713317
# The cost function is  47035.119643049795
# The cost function is  47017.42943840486
# The cost function is  46999.802952856175
# The cost function is  46982.23995689123
# The cost function is  46964.74022182419
# The cost function is  46947.30351979298
# The cost function is  46929.92962375623
# The cost function is  46912.618307490375
# The cost function is  46895.36934558668
# The cost function is  46878.182513448344
# The cost function is  46861.05758728753
# The cost function is  46843.99434412249
# The cost function is  46826.99256177462
# The cost function is  46810.05201886561
# The cost function is  46793.17249481455
# The cost function is  46776.35376983501
# The cost function is  46759.59562493224
# The cost function is  46742.89784190033
# The cost function is  46726.26020331928
# The cost function is  46709.68249255227
# The cost function is  46693.16449374274
# The cost function is  46676.70599181169
# The cost function is  46660.30677245478
# The cost function is  46643.966622139626
# The cost function is  46627.685328102925
# The cost function is  46611.462678347765
# The cost function is  46595.298461640836
# The cost function is  46579.19246750966
# The cost function is  46563.14448623987
# The cost function is  46547.15430887251
# The cost function is  46531.22172720125
# The cost function is  46515.34653376972
# The cost function is  46499.52852186877
# The cost function is  46483.767485533856
# The cost function is  46468.06321954227
# The cost function is  46452.4155194105
# The cost function is  46436.82418139158
# The cost function is  46421.28900247246
# The cost function is  46405.80978037127
# The cost function is  46390.386313534815
# The cost function is  46375.018401135836
# The cost function is  46359.705843070435
# The cost function is  46344.44843995551
# The cost function is  46329.24599312611
# The cost function is  46314.09830463288
# The cost function is  46299.00517723944
# The cost function is  46283.96641441986
# The cost function is  46268.981820356086
# The cost function is  46254.05119993538
# The cost function is  46239.1743587478
# The cost function is  46224.351103083645
# The cost function is  46209.58123993095
# The cost function is  46194.864576972985
# The cost function is  46180.20092258571
# The cost function is  46165.59008583531
# The cost function is  46151.0318764757
# The cost function is  46136.52610494607
# The cost function is  46122.07258236838
# The cost function is  46107.67112054491
# The cost function is  46093.32153195583
# The cost function is  46079.023629756746
# The cost function is  46064.77722777626
# The cost function is  46050.58214051357
# The cost function is  46036.438183136015
# The cost function is  46022.345171476685
# The cost function is  46008.302922032075
# The cost function is  45994.31125195958
# The cost function is  45980.36997907526
# The cost function is  45966.47892185133
# The cost function is  45952.637899413865
# The cost function is  45938.846731540485
# The cost function is  45925.10523865789
# The cost function is  45911.413241839655
# The cost function is  45897.770562803824
# The cost function is  45884.177023910546
# The cost function is  45870.632448159915
# The cost function is  45857.136659189484
# The cost function is  45843.68948127209
# The cost function is  45830.29073931353
# The cost function is  45816.940258850285
# The cost function is  45803.63786604722
# The cost function is  45790.383387695365
# The cost function is  45777.17665120962
# The cost function is  45764.01748462655
# The cost function is  45750.90571660212
# The cost function is  45737.841176409434
# The cost function is  45724.823693936596
# The cost function is  45711.85309968437
# The cost function is  45698.92922476414
# The cost function is  45686.051900895545
# The cost function is  45673.22096040438
# The cost function is  45660.43623622041
# The cost function is  45647.69756187515
# The cost function is  45635.00477149975
# The cost function is  45622.357699822795
# The cost function is  45609.75618216816
# The cost function is  45597.2000544529
# The cost function is  45584.689153185056
# The cost function is  45572.22331546162
# The cost function is  45559.80237896623
# The cost function is  45547.42618196733
# The cost function is  45535.09456331577
# The cost function is  45522.80736244297
# The cost function is  45510.56441935861
# The cost function is  45498.36557464873
# The cost function is  45486.210669473505
# The cost function is  45474.099545565274
# The cost function is  45462.032045226435
# The cost function is  45450.00801132742
# The cost function is  45438.027287304605
# The cost function is  45426.08971715832
# The cost function is  45414.1951454508
# The cost function is  45402.34341730415
# The cost function is  45390.53437839833
# The cost function is  45378.767874969155
# The cost function is  45367.0437538063
# The cost function is  45355.36186225129
# The cost function is  45343.722048195516
# The cost function is  45332.12416007822
# The cost function is  45320.568046884655
# The cost function is  45309.0535581439
# The cost function is  45297.58054392709
# The cost function is  45286.14885484541
# The cost function is  45274.75834204808
# The cost function is  45263.408857220515
# The cost function is  45252.10025258233
# The cost function is  45240.83238088543
# The cost function is  45229.60509541214
# The cost function is  45218.418249973205
# The cost function is  45207.271698905955
# The cost function is  45196.165297072395
# The cost function is  45185.0988998573
# The cost function is  45174.07236316634
# The cost function is  45163.08554342421
# The cost function is  45152.13829757275
# The cost function is  45141.2304830691
# The cost function is  45130.361957883804
# The cost function is  45119.532580499006
# The cost function is  45108.7422099066
# The cost function is  45097.990705606375
# The cost function is  45087.27792760417
# The cost function is  45076.6037364101
# The cost function is  45065.96799303674
# The cost function is  45055.3705589972
# The cost function is  45044.81129630351
# The cost function is  45034.29006746468
# The cost function is  45023.806735484955
# The cost function is  45013.36116386205
# The cost function is  45002.95321658531
# The cost function is  44992.58275813404
# The cost function is  44982.249653475636
# The cost function is  44971.9537680639
# The cost function is  44961.69496783725
# The cost function is  44951.473119216986
# The cost function is  44941.28808910557
# The cost function is  44931.13974488484
# The cost function is  44921.027954414334
# The cost function is  44910.952586029554
# The cost function is  44900.913508540274
# The cost function is  44890.91059122876
# The cost function is  44880.94370384814
# The cost function is  44871.012716620695
# The cost function is  44861.11750023613
# The cost function is  44851.257925849925
# The cost function is  44841.433865081686
# The cost function is  44831.64519001339
# The cost function is  44821.8917731878
# The cost function is  44812.17348760676
# The cost function is  44802.49020672953
# The cost function is  44792.84180447122
# The cost function is  44783.228155201046
# The cost function is  44773.64913374074
# The cost function is  44764.10461536295
# The cost function is  44754.59447578955
# The cost function is  44745.11859119006
# The cost function is  44735.67683818005
# The cost function is  44726.26909381952
# The cost function is  44716.89523561126
# The cost function is  44707.55514149931
# The cost function is  44698.24868986734
# The cost function is  44688.97575953709
# The cost function is  44679.73622976675
# The cost function is  44670.52998024944
# The cost function is  44661.35689111161
# The cost function is  44652.21684291148
# The cost function is  44643.1097166375
# The cost function is  44634.035393706785
# The cost function is  44624.99375596362
# The cost function is  44615.9846856778
# The cost function is  44607.00806554327
# The cost function is  44598.063778676405
# The cost function is  44589.151708614685
# The cost function is  44580.271739315016
# The cost function is  44571.423755152304
# The cost function is  44562.60764091794
# The cost function is  44553.82328181828
# The cost function is  44545.07056347316
# The cost function is  44536.34937191441
# The cost function is  44527.65959358436
# The cost function is  44519.00111533436
# The cost function is  44510.37382442337
# The cost function is  44501.77760851636
# The cost function is  44493.21235568295
# The cost function is  44484.677954395964
# The cost function is  44476.17429352991
# The cost function is  44467.70126235956
# The cost function is  44459.258750558496
# The cost function is  44450.84664819774
# The cost function is  44442.46484574424
# The cost function is  44434.113234059456
# The cost function is  44425.791704398005
# The cost function is  44417.500148406165
# The cost function is  44409.23845812051
# The cost function is  44401.00652596649
# The cost function is  44392.80424475703
# The cost function is  44384.63150769114
# The cost function is  44376.48820835252
# The cost function is  44368.37424070819
# The cost function is  44360.28949910705
# The cost function is  44352.233878278596
# The cost function is  44344.207273331485
# The cost function is  44336.20957975218
# The cost function is  44328.24069340361
# The cost function is  44320.3005105238
# The cost function is  44312.38892772449
# The cost function is  44304.50584198987
# The cost function is  44296.65115067513
# The cost function is  44288.8247515052
# The cost function is  44281.026542573454
# The cost function is  44273.25642234024
# The cost function is  44265.514289631705
# The cost function is  44257.8000436384
# The cost function is  44250.11358391396
# The cost function is  44242.454810373885
# The cost function is  44234.82362329412
# The cost function is  44227.219923309814
# The cost function is  44219.64361141407
# The cost function is  44212.094588956534
# The cost function is  44204.57275764225
# The cost function is  44197.07801953028
# The cost function is  44189.61027703249
# The cost function is  44182.169432912204
# The cost function is  44174.75539028303
# The cost function is  44167.36805260757
# The cost function is  44160.007323696074
# The cost function is  44152.67310770535
# The cost function is  44145.36530913738
# The cost function is  44138.08383283812
# The cost function is  44130.82858399627
# The cost function is  44123.59946814207
# The cost function is  44116.396391145994
# The cost function is  44109.21925921757
# The cost function is  44102.06797890416
# The cost function is  44094.94245708975
# The cost function is  44087.8426009937
# The cost function is  44080.76831816959
# The cost function is  44073.71951650397
# The cost function is  44066.69610421517
# The cost function is  44059.6979898521
# The cost function is  44052.72508229313
# The cost function is  44045.77729074478
# The cost function is  44038.85452474064
# The cost function is  44031.95669414012
# The cost function is  44025.08370912738
# The cost function is  44018.23548021001
# The cost function is  44011.411918218
# The cost function is  44004.61293430251
# The cost function is  43997.838439934705
# The cost function is  43991.08834690468
# The cost function is  43984.36256732019
# The cost function is  43977.66101360565
# The cost function is  43970.98359850082
# The cost function is  43964.33023505987
# The cost function is  43957.70083665007
# The cost function is  43951.09531695076
# The cost function is  43944.51358995221
# The cost function is  43937.95556995449
# The cost function is  43931.42117156633
# The cost function is  43924.910309704086
# The cost function is  43918.42289959053
# The cost function is  43911.95885675381
# The cost function is  43905.51809702636
# The cost function is  43899.10053654377
# The cost function is  43892.70609174367
# The cost function is  43886.33467936473
# The cost function is  43879.98621644549
# The cost function is  43873.66062032332
# The cost function is  43867.35780863334
# The cost function is  43861.07769930734
# The cost function is  43854.8202105727
# The cost function is  43848.585260951375
# The cost function is  43842.37276925878
# The cost function is  43836.18265460274
# The cost function is  43830.01483638246
# The cost function is  43823.86923428747
# The cost function is  43817.74576829659
# The cost function is  43811.644358676815
# The cost function is  43805.56492598238
# The cost function is  43799.50739105366
# The cost function is  43793.471675016204
# The cost function is  43787.45769927959
# The cost function is  43781.465385536525
# The cost function is  43775.49465576173
# The cost function is  43769.54543221103
# The cost function is  43763.61763742024
# The cost function is  43757.711194204196
# The cost function is  43751.82602565576
# The cost function is  43745.9620551448
# The cost function is  43740.119206317235
# The cost function is  43734.29740309396
# The cost function is  43728.49656966991
# The cost function is  43722.716630513096
# The cost function is  43716.957510363565
# The cost function is  43711.219134232466
# The cost function is  43705.50142740103
# The cost function is  43699.80431541965
# The cost function is  43694.12772410683
# The cost function is  43688.47157954834
# The cost function is  43682.83580809614
# The cost function is  43677.22033636748
# The cost function is  43671.62509124393
# The cost function is  43666.0499998704
# The cost function is  43660.494989654275
# The cost function is  43654.959988264374
# The cost function is  43649.44492363005
# The cost function is  43643.94972394028
# The cost function is  43638.474317642664
# The cost function is  43633.018633442545
# The cost function is  43627.58260030208
# The cost function is  43622.166147439275
# The cost function is  43616.769204327116
# The cost function is  43611.391700692584
# The cost function is  43606.0335665158
# The cost function is  43600.69473202913
# The cost function is  43595.37512771617
# The cost function is  43590.07468431095
# The cost function is  43584.79333279702
# The cost function is  43579.53100440643
# The cost function is  43574.28763061902
# The cost function is  43569.063143161424
# The cost function is  43563.85747400613
# The cost function is  43558.67055537072
# The cost function is  43553.50231971692
# The cost function is  43548.35269974969
# The cost function is  43543.22162841639
# The cost function is  43538.10903890592
# The cost function is  43533.01486464784
# The cost function is  43527.93903931143
# The cost function is  43522.881496804985
# The cost function is  43517.842171274766
# The cost function is  43512.82099710431
# The cost function is  43507.817908913436
# The cost function is  43502.8328415575
# The cost function is  43497.86573012651
# The cost function is  43492.91650994423
# The cost function is  43487.98511656744
# The cost function is  43483.07148578502
# The cost function is  43478.1755536171
# The cost function is  43473.297256314305
# The cost function is  43468.43653035689
# The cost function is  43463.59331245385
# The cost function is  43458.767539542205
# The cost function is  43453.9591487861
# The cost function is  43449.16807757601
# The cost function is  43444.39426352792
# The cost function is  43439.63764448255
# The cost function is  43434.898158504475
# The cost function is  43430.175743881395
# The cost function is  43425.47033912325
# The cost function is  43420.7818829615
# The cost function is  43416.11031434827
# The cost function is  43411.455572455605
# The cost function is  43406.81759667461
# The cost function is  43402.19632661473
# The cost function is  43397.59170210292
# The cost function is  43393.00366318286
# The cost function is  43388.432150114226
# The cost function is  43383.87710337185
# The cost function is  43379.33846364497
# The cost function is  43374.816171836464
# The cost function is  43370.310169062075
# The cost function is  43365.82039664965
# The cost function is  43361.34679613834
# The cost function is  43356.88930927791
# The cost function is  43352.44787802792
# The cost function is  43348.02244455697
# The cost function is  43343.612951242016
# The cost function is  43339.21934066748
# The cost function is  43334.841555624706
# The cost function is  43330.47953911102
# The cost function is  43326.13323432908
# The cost function is  43321.80258468615
# The cost function is  43317.487533793304
# The cost function is  43313.18802546476
# The cost function is  43308.90400371711
# The cost function is  43304.63541276855
# The cost function is  43300.382197038256
# The cost function is  43296.14430114558
# The cost function is  43291.92166990934
# The cost function is  43287.71424834712
# The cost function is  43283.52198167457
# The cost function is  43279.34481530465
# The cost function is  43275.18269484691
# The cost function is  43271.0355661069
# The cost function is  43266.90337508526
# The cost function is  43262.78606797721
# The cost function is  43258.68359117177
# The cost function is  43254.595891251025
# The cost function is  43250.5229149895
# The cost function is  43246.46460935343
# The cost function is  43242.42092150007
# The cost function is  43238.39179877697
# The cost function is  43234.37718872142
# The cost function is  43230.3770390596
# The cost function is  43226.39129770603
# The cost function is  43222.419912762794
# The cost function is  43218.46283251894
# The cost function is  43214.52000544977
# The cost function is  43210.59138021616
# The cost function is  43206.67690566392
# The cost function is  43202.77653082313
# The cost function is  43198.89020490742
# The cost function is  43195.01787731338
# The cost function is  43191.159497619876
# The cost function is  43187.31501558735
# The cost function is  43183.48438115725
# The cost function is  43179.66754445131
# The cost function is  43175.86445577091
# The cost function is  43172.075065596466
# The cost function is  43168.299324586755
# The cost function is  43164.537183578264
# The cost function is  43160.78859358456
# The cost function is  43157.05350579571
# The cost function is  43153.33187157753
# The cost function is  43149.623642471015
# The cost function is  43145.92877019174
# The cost function is  43142.247206629196
# The cost function is  43138.57890384614
# The cost function is  43134.923814078014
# The cost function is  43131.2818897323
# The cost function is  43127.65308338791
# The cost function is  43124.03734779456
# The cost function is  43120.43463587215
# The cost function is  43116.84490071018
# The cost function is  43113.2680955671
# The cost function is  43109.704173869744
# The cost function is  43106.15308921266
# The cost function is  43102.61479535758
# The cost function is  43099.089246232776
# The cost function is  43095.57639593246
# The cost function is  43092.076198716204
# The cost function is  43088.58860900833
# The cost function is  43085.11358139733
# The cost function is  43081.65107063522
# The cost function is  43078.20103163707
# The cost function is  43074.763419480296
# The cost function is  43071.33818940412
# The cost function is  43067.92529680902
# The cost function is  43064.52469725609
# The cost function is  43061.1363464665
# The cost function is  43057.760200320925
# The cost function is  43054.39621485892
# The cost function is  43051.044346278424
# The cost function is  43047.70455093512
# The cost function is  43044.37678534191
# The cost function is  43041.06100616832
# The cost function is  43037.757170239965
# The cost function is  43034.46523453795
# The cost function is  43031.18515619838
# The cost function is  43027.91689251169
# The cost function is  43024.66040092218
# The cost function is  43021.41563902745
# The cost function is  43018.18256457783
# The cost function is  43014.96113547579
# The cost function is  43011.75130977546
# The cost function is  43008.553045682085
# The cost function is  43005.36630155139
# The cost function is  43002.191035889155
# The cost function is  42999.02720735059
# The cost function is  42995.87477473985
# The cost function is  42992.73369700944
# The cost function is  42989.60393325975
# The cost function is  42986.48544273846
# The cost function is  42983.37818484007
# The cost function is  42980.28211910532
# The cost function is  42977.19720522068
# The cost function is  42974.123403017795
# The cost function is  42971.06067247309
# The cost function is  42968.008973707045
# The cost function is  42964.96826698385
# The cost function is  42961.93851271079
# The cost function is  42958.91967143779
# The cost function is  42955.91170385683
# The cost function is  42952.914570801506
# The cost function is  42949.928233246486
# The cost function is  42946.952652307
# The cost function is  42943.98778923835
# The cost function is  42941.033605435376
# The cost function is  42938.09006243198
# The cost function is  42935.15712190059
# The cost function is  42932.23474565175
# The cost function is  42929.32289563351
# The cost function is  42926.421533931
# The cost function is  42923.530622765895
# The cost function is  42920.65012449599
# The cost function is  42917.78000161461
# The cost function is  42914.92021675022
# The cost function is  42912.07073266588
# The cost function is  42909.231512258775
# The cost function is  42906.40251855972
# The cost function is  42903.583714732704
# The cost function is  42900.77506407441
# The cost function is  42897.9765300137
# The cost function is  42895.18807611118
# The cost function is  42892.409666058695
# The cost function is  42889.64126367888
# The cost function is  42886.88283292468
# The cost function is  42884.134337878866
# The cost function is  42881.395742753586
# The cost function is  42878.66701188991
# The cost function is  42875.94810975735
# The cost function is  42873.23900095335
# The cost function is  42870.539650202925
# The cost function is  42867.850022358114
# The cost function is  42865.1700823976
# The cost function is  42862.49979542616
# The cost function is  42859.839126674284
# The cost function is  42857.18804149773
# The cost function is  42854.546505376966
# The cost function is  42851.91448391688
# The cost function is  42849.2919428462
# The cost function is  42846.67884801711
# The cost function is  42844.0751654048
# The cost function is  42841.480861107004
# The cost function is  42838.89590134357
# The cost function is  42836.320252456026
# The cost function is  42833.75388090714
# The cost function is  42831.19675328047
# The cost function is  42828.64883627994
# The cost function is  42826.110096729404
# The cost function is  42823.580501572236
# The cost function is  42821.06001787083
# The cost function is  42818.548612806255
# The cost function is  42816.04625367781
# The cost function is  42813.55290790254
# The cost function is  42811.06854301484
# The cost function is  42808.59312666611
# The cost function is  42806.12662662421
# The cost function is  42803.66901077313
# The cost function is  42801.220247112506
# The cost function is  42798.78030375728
# The cost function is  42796.3491489372
# The cost function is  42793.9267509965
# The cost function is  42791.51307839338
# The cost function is  42789.10809969969
# The cost function is  42786.71178360046
# The cost function is  42784.32409889353
# The cost function is  42781.945014489116
# The cost function is  42779.57449940945
# The cost function is  42777.21252278829
# The cost function is  42774.85905387063
# The cost function is  42772.51406201217
# The cost function is  42770.17751667906
# The cost function is  42767.84938744741
# The cost function is  42765.52964400289
# The cost function is  42763.21825614038
# The cost function is  42760.915193763576
# The cost function is  42758.62042688455
# The cost function is  42756.33392562338
# The cost function is  42754.05566020782
# The cost function is  42751.78560097279
# The cost function is  42749.52371836013
# The cost function is  42747.2699829181
# The cost function is  42745.024365301084
# The cost function is  42742.78683626913
# The cost function is  42740.557366687615
# The cost function is  42738.33592752689
# The cost function is  42736.1224898618
# The cost function is  42733.91702487146
# The cost function is  42731.71950383873
# The cost function is  42729.52989814995
# The cost function is  42727.3481792945
# The cost function is  42725.174318864476
# The cost function is  42723.00828855425
# The cost function is  42720.850060160206
# The cost function is  42718.69960558029
# The cost function is  42716.55689681367
# The cost function is  42714.42190596038
# The cost function is  42712.29460522092
# The cost function is  42710.17496689597
# The cost function is  42708.062963385935
# The cost function is  42705.958567190675
# The cost function is  42703.86175090906
# The cost function is  42701.77248723869
# The cost function is  42699.69074897548
# The cost function is  42697.61650901337
# The cost function is  42695.5497403439
# The cost function is  42693.4904160559
# The cost function is  42691.438509335145
# The cost function is  42689.39399346399
# The cost function is  42687.35684182101
# The cost function is  42685.327027880696
# The cost function is  42683.30452521305
# The cost function is  42681.28930748329
# The cost function is  42679.281348451506
# The cost function is  42677.28062197227
# The cost function is  42675.287101994356
# The cost function is  42673.30076256035
# The cost function is  42671.321577806375
# The cost function is  42669.349521961645
# The cost function is  42667.384569348265
# The cost function is  42665.42669438081
# The cost function is  42663.47587156601
# The cost function is  42661.532075502386
# The cost function is  42659.59528088002
# The cost function is  42657.66546248012
# The cost function is  42655.74259517472
# The cost function is  42653.826653926386
# The cost function is  42651.91761378787
# The cost function is  42650.01544990175
# The cost function is  42648.1201375002
# The cost function is  42646.23165190452
# The cost function is  42644.349968524984
# The cost function is  42642.47506286039
# The cost function is  42640.606910497794
# The cost function is  42638.7454871122
# The cost function is  42636.89076846622
# The cost function is  42635.042730409776
# The cost function is  42633.20134887977
# The cost function is  42631.36659989975
# The cost function is  42629.538459579686
# The cost function is  42627.71690411555
# The cost function is  42625.90190978907
# The cost function is  42624.09345296742
# The cost function is  42622.291510102885
# The cost function is  42620.496057732555
# The cost function is  42618.70707247804
# The cost function is  42616.92453104517
# The cost function is  42615.14841022369
# The cost function is  42613.37868688689
# The cost function is  42611.61533799144
# The cost function is  42609.85834057693
# The cost function is  42608.10767176573
# The cost function is  42606.36330876254
# The cost function is  42604.62522885423
# The cost function is  42602.89340940946
# The cost function is  42601.16782787837
# The cost function is  42599.44846179238
# The cost function is  42597.73528876382
# The cost function is  42596.028286485634
# The cost function is  42594.32743273114
# The cost function is  42592.63270535371
# The cost function is  42590.94408228651
# The cost function is  42589.26154154213
# The cost function is  42587.585061212434
# The cost function is  42585.91461946812
# The cost function is  42584.25019455858
# The cost function is  42582.59176481151
# The cost function is  42580.939308632675
# The cost function is  42579.29280450564
# The cost function is  42577.65223099146
# The cost function is  42576.01756672839
# The cost function is  42574.388790431665
# The cost function is  42572.76588089316
# The cost function is  42571.148816981164
# The cost function is  42569.53757764006
# The cost function is  42567.93214189007
# The cost function is  42566.332488827014
# The cost function is  42564.73859762197
# The cost function is  42563.15044752107
# The cost function is  42561.56801784517
# The cost function is  42559.99128798966
# The cost function is  42558.420237424085
# The cost function is  42556.854845691996
# The cost function is  42555.295092410575
# The cost function is  42553.74095727047
# The cost function is  42552.19242003545
# The cost function is  42550.64946054218
# The cost function is  42549.112058699975
# The cost function is  42547.580194490474
# The cost function is  42546.05384796746
# The cost function is  42544.532999256524
# The cost function is  42543.01762855489
# The cost function is  42541.507716131055
# The cost function is  42540.00324232466
# The cost function is  42538.504187546074
# The cost function is  42537.010532276305
# The cost function is  42535.52225706663
# The cost function is  42534.03934253836
# The cost function is  42532.561769382635
# The cost function is  42531.089518360146
# The cost function is  42529.62257030089
# The cost function is  42528.16090610388
# The cost function is  42526.70450673696
# The cost function is  42525.25335323652
# The cost function is  42523.80742670724
# The cost function is  42522.36670832187
# The cost function is  42520.931179320985
# The cost function is  42519.500821012705
# The cost function is  42518.075614772526
# The cost function is  42516.65554204296
# The cost function is  42515.24058433343
# The cost function is  42513.8307232199
# The cost function is  42512.42594034476
# The cost function is  42511.026217416445
# The cost function is  42509.63153620935
# The cost function is  42508.24187856348
# The cost function is  42506.85722638425
# The cost function is  42505.47756164226
# The cost function is  42504.10286637306
# The cost function is  42502.73312267688
# The cost function is  42501.36831271845
# The cost function is  42500.00841872673
# The cost function is  42498.653422994685
# The cost function is  42497.30330787909
# The cost function is  42495.95805580019
# The cost function is  42494.61764924168
# The cost function is  42493.28207075022
# The cost function is  42491.95130293542
# The cost function is  42490.6253284695
# The cost function is  42489.30413008707
# The cost function is  42487.98769058497
# The cost function is  42486.67599282198
# The cost function is  42485.36901971865
# The cost function is  42484.066754257015
# The cost function is  42482.76917948041
# The cost function is  42481.476278493275
# The cost function is  42480.18803446088
# The cost function is  42478.904430609145
# The cost function is  42477.62545022441
# The cost function is  42476.35107665322
# The cost function is  42475.08129330207
# The cost function is  42473.8160836373
# The cost function is  42472.555431184715
# The cost function is  42471.29931952951
# The cost function is  42470.047732316
# The cost function is  42468.8006532474
# The cost function is  42467.55806608565
# The cost function is  42466.319954651146
# The cost function is  42465.08630282256
# The cost function is  42463.85709453669
# The cost function is  42462.632313788126
# The cost function is  42461.41194462912
# The cost function is  42460.19597116942
# The cost function is  42458.98437757594
# The cost function is  42457.77714807266
# The cost function is  42456.574266940384
# The cost function is  42455.37571851653
# The cost function is  42454.18148719493
# The cost function is  42452.991557425645
# The cost function is  42451.805913714714
# The cost function is  42450.62454062399
# The cost function is  42449.44742277098
# The cost function is  42448.27454482854
# The cost function is  42447.10589152477
# The cost function is  42445.94144764275
# The cost function is  42444.781198020406
# The cost function is  42443.62512755023
# The cost function is  42442.47322117918
# The cost function is  42441.32546390839
# The cost function is  42440.18184079307
# The cost function is  42439.04233694221
# The cost function is  42437.906937518455
# The cost function is  42436.77562773791
# The cost function is  42435.648392869894
# The cost function is  42434.52521823684
# The cost function is  42433.40608921398
# The cost function is  42432.29099122928
# The cost function is  42431.179909763174
# The cost function is  42430.07283034841
# The cost function is  42428.96973856977
# The cost function is  42427.87062006409
# The cost function is  42426.77546051981
# The cost function is  42425.68424567703
# The cost function is  42424.59696132714
# The cost function is  42423.51359331271
# The cost function is  42422.43412752737
# The cost function is  42421.35854991549
# The cost function is  42420.28684647209
# The cost function is  42419.21900324266
# The cost function is  42418.15500632291
# The cost function is  42417.09484185865
# The cost function is  42416.03849604563
# The cost function is  42414.985955129254
# The cost function is  42413.93720540452
# The cost function is  42412.892233215774
# The cost function is  42411.851024956544
# The cost function is  42410.81356706939
# The cost function is  42409.77984604566
# The cost function is  42408.7498484254
# The cost function is  42407.72356079714
# The cost function is  42406.700969797675
# The cost function is  42405.682062112
# The cost function is  42404.666824472995
# The cost function is  42403.65524366138
# The cost function is  42402.64730650547
# The cost function is  42401.64299988103
# The cost function is  42400.64231071109
# The cost function is  42399.64522596579
# The cost function is  42398.651732662205
# The cost function is  42397.66181786417
# The cost function is  42396.6754686821
# The cost function is  42395.692672272875
# The cost function is  42394.71341583959
# The cost function is  42393.737686631466
# The cost function is  42392.76547194365
# The cost function is  42391.79675911703
# The cost function is  42390.83153553811
# The cost function is  42389.86978863881
# The cost function is  42388.91150589635
# The cost function is  42387.95667483302
# The cost function is  42387.00528301608
# The cost function is  42386.05731805755
# The cost function is  42385.11276761412
# The cost function is  42384.171619386856
# The cost function is  42383.233861121196
# The cost function is  42382.299480606714
# The cost function is  42381.36846567689
# The cost function is  42380.44080420913
# The cost function is  42379.51648412444
# The cost function is  42378.59549338736
# The cost function is  42377.67782000577
# The cost function is  42376.763452030726
# The cost function is  42375.852377556366
# The cost function is  42374.94458471969
# The cost function is  42374.04006170043
# The cost function is  42373.13879672087
# The cost function is  42372.240778045765
# The cost function is  42371.34599398211
# The cost function is  42370.454432879
# The cost function is  42369.566083127545
# The cost function is  42368.68093316062
# The cost function is  42367.7989714528
# The cost function is  42366.92018652016
# The cost function is  42366.04456692012
# The cost function is  42365.17210125136
# The cost function is  42364.302778153586
# The cost function is  42363.43658630743
# The cost function is  42362.573514434334
# The cost function is  42361.71355129631
# The cost function is  42360.85668569588
# The cost function is  42360.00290647589
# The cost function is  42359.15220251939
# The cost function is  42358.30456274945
# The cost function is  42357.45997612903
# The cost function is  42356.618431660885
# The cost function is  42355.77991838736
# The cost function is  42354.94442539024
# The cost function is  42354.111941790674
# The cost function is  42353.28245674901
# The cost function is  42352.45595946459
# The cost function is  42351.63243917569
# The cost function is  42350.81188515936
# The cost function is  42349.99428673123
# The cost function is  42349.179633245454
# The cost function is  42348.36791409453
# The cost function is  42347.559118709134
# The cost function is  42346.75323655804
# The cost function is  42345.950257147975
# The cost function is  42345.15017002337
# The cost function is  42344.35296476643
# The cost function is  42343.55863099681
# The cost function is  42342.7671583716
# The cost function is  42341.97853658512
# The cost function is  42341.192755368786
# The cost function is  42340.40980449105
# The cost function is  42339.6296737572
# The cost function is  42338.85235300922
# The cost function is  42338.07783212573
# The cost function is  42337.306101021764
# The cost function is  42336.5371496487
# The cost function is  42335.77096799409
# The cost function is  42335.00754608159
# The cost function is  42334.24687397077
# The cost function is  42333.488941757
# The cost function is  42332.73373957131
# The cost function is  42331.98125758032
# The cost function is  42331.231485986034
# The cost function is  42330.48441502576
# The cost function is  42329.740034971976
# The cost function is  42328.99833613219
# The cost function is  42328.259308848814
# The cost function is  42327.52294349907
# The cost function is  42326.78923049482
# The cost function is  42326.05816028246
# The cost function is  42325.329723342824
# The cost function is  42324.603910191014
# The cost function is  42323.88071137628
# The cost function is  42323.160117481944
# The cost function is  42322.44211912524
# The cost function is  42321.726706957175
# The cost function is  42321.01387166245
# The cost function is  42320.30360395933
# The cost function is  42319.595894599464
# The cost function is  42318.890734367895
# The cost function is  42318.188114082775
# The cost function is  42317.48802459538
# The cost function is  42316.79045678992
# The cost function is  42316.09540158343
# The cost function is  42315.40284992569
# The cost function is  42314.71279279905
# The cost function is  42314.025221218355
# The cost function is  42313.34012623082
# The cost function is  42312.65749891589
# The cost function is  42311.977330385154
# The cost function is  42311.29961178222
# The cost function is  42310.62433428258
# The cost function is  42309.95148909353
# The cost function is  42309.281067454016
# The cost function is  42308.613060634554
# The cost function is  42307.94745993712
# The cost function is  42307.28425669496
# The cost function is  42306.62344227263
# The cost function is  42305.9650080657
# ...
# The cost function is  42130.676813623955
# The cost function is  42130.6521290197
# The cost function is  42130.62753332798
# The cost function is  42130.60302622851
# The cost function is  42130.578607402196
# The cost function is  42130.55427653109
# The cost function is  42130.530033298375
# The cost function is  42130.50587738839
# The cost function is  42130.4818084866
# The cost function is  42130.4578262796
# The cost function is  42130.433930455125
# The cost function is  42130.41012070203
# The cost function is  42130.386396710295
# The cost function is  42130.36275817101
# The cost function is  42130.33920477638
# The cost function is  42130.31573621971
# The cost function is  42130.29235219542
# The cost function is  42130.26905239906
# The cost function is  42130.24583652721
# The cost function is  42130.222704277585
# The cost function is  42130.199655349
# The cost function is  42130.176689441316
# The cost function is  42130.15380625551
# The cost function is  42130.13100549362
# The cost function is  42130.10828685875
# The cost function is  42130.0856500551
# The cost function is  42130.06309478792
# The cost function is  42130.0406207635
# The cost function is  42130.018227689216
# The cost function is  42129.995915273495
# The cost function is  42129.9736832258
# The cost function is  42129.951531256665
# The cost function is  42129.929459077655
# The cost function is  42129.90746640134
# The cost function is  42129.88555294141
# The cost function is  42129.86371841246
# The cost function is  42129.84196253024
# The cost function is  42129.820285011454
# The cost function is  42129.79868557384
# The cost function is  42129.77716393615
# The cost function is  42129.75571981815
# The cost function is  42129.734352940635
# The cost function is  42129.713063025374
# The cost function is  42129.69184979517
# The cost function is  42129.670712973784
# The cost function is  42129.64965228602
# The cost function is  42129.628667457626
# The cost function is  42129.60775821538
# The cost function is  42129.58692428701
# The cost function is  42129.56616540125
# The cost function is  42129.545481287816
# The cost function is  42129.52487167735
# The cost function is  42129.504336301514
# The cost function is  42129.48387489292
# The cost function is  42129.46348718513
# The cost function is  42129.443172912695
# The cost function is  42129.422931811096
# The cost function is  42129.402763616774
# The cost function is  42129.382668067126
# The cost function is  42129.36264490048
# The cost function is  42129.34269385613
# The cost function is  42129.32281467429
# The cost function is  42129.30300709614
# The cost function is  42129.283270863714
# The cost function is  42129.263605720065
# The cost function is  42129.24401140913
# The cost function is  42129.22448767577
# The cost function is  42129.20503426577
# The cost function is  42129.18565092583
# The cost function is  42129.16633740357
# The cost function is  42129.14709344749
# The cost function is  42129.12791880704
# The cost function is  42129.10881323253
# The cost function is  42129.08977647519
# The cost function is  42129.07080828717
# The cost function is  42129.051908421476
# The cost function is  42129.033076632
# The cost function is  42129.01431267352
# The cost function is  42128.995616301756
# The cost function is  42128.97698727324
# The cost function is  42128.95842534541
# The cost function is  42128.939930276574
# The cost function is  42128.92150182591
# The cost function is  42128.90313975345
# The cost function is  42128.88484382012
# The cost function is  42128.86661378769
# The cost function is  42128.84844941879
# The cost function is  42128.83035047689
# The cost function is  42128.81231672634
# The cost function is  42128.79434793232
# The cost function is  42128.77644386085
# The cost function is  42128.75860427882
# The cost function is  42128.74082895393
# The cost function is  42128.723117654736
# The cost function is  42128.70547015062
# The cost function is  42128.68788621181
# The cost function is  42128.67036560931
# The cost function is  42128.65290811502
# The cost function is  42128.63551350162
# The cost function is  42128.61818154259
# The cost function is  42128.600912012305
# The cost function is  42128.583704685865
# The cost function is  42128.56655933921
# The cost function is  42128.54947574912
# The cost function is  42128.53245369313
# The cost function is  42128.515492949606
# The cost function is  42128.498593297685
# The cost function is  42128.48175451734
# The cost function is  42128.46497638933
# The cost function is  42128.448258695156
# The cost function is  42128.43160121715
# The cost function is  42128.41500373841
# The cost function is  42128.39846604284
# The cost function is  42128.3819879151
# The cost function is  42128.365569140624
# The cost function is  42128.34920950562
# The cost function is  42128.33290879708
# The cost function is  42128.316666802755
# The cost function is  42128.30048331115
# The cost function is  42128.28435811155
# The cost function is  42128.26829099399
# The cost function is  42128.25228174926
# The cost function is  42128.2363301689
# The cost function is  42128.22043604522
# The cost function is  42128.20459917125
# The cost function is  42128.1888193408
# The cost function is  42128.173096348364
# The cost function is  42128.15742998926
# The cost function is  42128.14182005947
# The cost function is  42128.12626635574
# The cost function is  42128.11076867557
# The cost function is  42128.09532681713
# The cost function is  42128.07994057939
# The cost function is  42128.06460976199
# The cost function is  42128.04933416529
# The cost function is  42128.034113590424
# The cost function is  42128.018947839184
# The cost function is  42128.00383671411
# The cost function is  42127.98878001843
# The cost function is  42127.9737775561
# The cost function is  42127.95882913178
# The cost function is  42127.943934550814
# The cost function is  42127.92909361928
# The cost function is  42127.914306143924
# The cost function is  42127.89957193218
# The cost function is  42127.884890792244
# The cost function is  42127.8702625329
# The cost function is  42127.855686963725
# The cost function is  42127.841163894904
# The cost function is  42127.82669313733
# The cost function is  42127.81227450259
# The cost function is  42127.79790780295
# The cost function is  42127.78359285133
# The cost function is  42127.76932946133
# The cost function is  42127.75511744725
# The cost function is  42127.74095662401
# The cost function is  42127.72684680725
# The cost function is  42127.71278781324
# The cost function is  42127.69877945891
# The cost function is  42127.684821561874
# The cost function is  42127.670913940354
# The cost function is  42127.65705641329
# The cost function is  42127.643248800254
# The cost function is  42127.629490921434
# The cost function is  42127.615782597706
# The cost function is  42127.60212365055
# The cost function is  42127.58851390215
# The cost function is  42127.574953175266
# The cost function is  42127.56144129335
# The cost function is  42127.54797808045
# The cost function is  42127.53456336127
# The cost function is  42127.52119696113
# The cost function is  42127.50787870598
# The cost function is  42127.494608422436
# The cost function is  42127.48138593768
# The cost function is  42127.46821107955
# The cost function is  42127.4550836765
# The cost function is  42127.4420035576
# The cost function is  42127.42897055252
# The cost function is  42127.415984491585
# The cost function is  42127.40304520568
# The cost function is  42127.390152526365
# The cost function is  42127.37730628571
# The cost function is  42127.36450631648
# The cost function is  42127.35175245201
# The cost function is  42127.33904452621
# The cost function is  42127.32638237362
# The cost function is  42127.31376582939
# The cost function is  42127.30119472921
# The cost function is  42127.288668909416
# The cost function is  42127.2761882069
# The cost function is  42127.263752459156
# The cost function is  42127.25136150426
# The cost function is  42127.239015180865
# The cost function is  42127.226713328215
# The cost function is  42127.214455786125
# The cost function is  42127.202242395004
# The cost function is  42127.19007299581
# The cost function is  42127.17794743008
# The cost function is  42127.16586553994
# The cost function is  42127.15382716808
# The cost function is  42127.14183215773
# The cost function is  42127.129880352724
# The cost function is  42127.11797159743
# The cost function is  42127.10610573677
# The cost function is  42127.09428261628
# The cost function is  42127.082502081976
# The cost function is  42127.07076398046
# The cost function is  42127.059068158924
# The cost function is  42127.04741446507
# The cost function is  42127.035802747145
# The cost function is  42127.02423285395
# The cost function is  42127.01270463484
# The cost function is  42127.00121793972
# The cost function is  42126.98977261901
# The cost function is  42126.978368523676
# The cost function is  42126.967005505256
# The cost function is  42126.955683415756
# The cost function is  42126.944402107765
# The cost function is  42126.933161434405
# The cost function is  42126.921961249296
# The cost function is  42126.9108014066
# The cost function is  42126.89968176103
# The cost function is  42126.88860216778
# The cost function is  42126.87756248259
# The cost function is  42126.86656256169
# The cost function is  42126.85560226187
# The cost function is  42126.84468144043
# The cost function is  42126.83379995516
# The cost function is  42126.822957664364
# The cost function is  42126.81215442688
# The cost function is  42126.80139010203
# The cost function is  42126.79066454967
# The cost function is  42126.77997763012
# The cost function is  42126.76932920423
# The cost function is  42126.758719133366
# The cost function is  42126.74814727935
# The cost function is  42126.737613504556
# The cost function is  42126.72711767181
# The cost function is  42126.71665964445
# The cost function is  42126.70623928629
# The cost function is  42126.69585646167
# The cost function is  42126.68551103538
# The cost function is  42126.67520287272
# The cost function is  42126.66493183946
# The cost function is  42126.65469780187
# The cost function is  42126.6445006267
# The cost function is  42126.634340181176
# The cost function is  42126.62421633297
# The cost function is  42126.61412895029
# The cost function is  42126.60407790179
# The cost function is  42126.594063056575
# The cost function is  42126.58408428426
# The cost function is  42126.57414145489
# The cost function is  42126.56423443904
# The cost function is  42126.55436310768
# The cost function is  42126.544527332284
# The cost function is  42126.53472698479
# The cost function is  42126.524961937575
# The cost function is  42126.5152320635
# The cost function is  42126.50553723587
# The cost function is  42126.49587732844
# The cost function is  42126.48625221546
# The cost function is  42126.476661771565
# The cost function is  42126.4671058719
# The cost function is  42126.45758439203
# The cost function is  42126.44809720799
# The cost function is  42126.43864419624
# The cost function is  42126.42922523369
# The cost function is  42126.41984019769
# The cost function is  42126.41048896606
# The cost function is  42126.401171417005
# The cost function is  42126.39188742924
# The cost function is  42126.38263688188
# The cost function is  42126.37341965443
# The cost function is  42126.36423562691
# The cost function is  42126.355084679744
# The cost function is  42126.345966693734
# The cost function is  42126.3368815502
# The cost function is  42126.32782913083
# The cost function is  42126.318809317745
# The cost function is  42126.309821993505
# The cost function is  42126.3008670411
# The cost function is  42126.29194434392
# The cost function is  42126.28305378575
# The cost function is  42126.27419525088
# The cost function is  42126.26536862395
# The cost function is  42126.25657379001
# The cost function is  42126.247810634544
# The cost function is  42126.239079043466
# The cost function is  42126.230378903085
# The cost function is  42126.2217101001
# The cost function is  42126.213072521634
# The cost function is  42126.20446605524
# The cost function is  42126.19589058883
# The cost function is  42126.18734601077
# The cost function is  42126.17883220978
# The cost function is  42126.170349075
# The cost function is  42126.161896496
# The cost function is  42126.1534743627
# The cost function is  42126.145082565425
# The cost function is  42126.13672099492
# The cost function is  42126.12838954232
# The cost function is  42126.120088099124
# The cost function is  42126.11181655724
# The cost function is  42126.10357480899
# The cost function is  42126.09536274703
# The cost function is  42126.08718026444
# The cost function is  42126.079027254695
# The cost function is  42126.07090361161
# The cost function is  42126.06280922943
# The cost function is  42126.05474400272
# The cost function is  42126.04670782652
# The cost function is  42126.03870059616
# The cost function is  42126.03072220737
# The cost function is  42126.02277255628
# The cost function is  42126.014851539374
# The cost function is  42126.00695905351
# The cost function is  42125.99909499594
# The cost function is  42125.991259264236
# The cost function is  42125.983451756394
# The cost function is  42125.97567237074
# The cost function is  42125.967921005984
# The cost function is  42125.960197561195
# The cost function is  42125.95250193581
# The cost function is  42125.94483402962
# The cost function is  42125.93719374279
# The cost function is  42125.92958097584
# The cost function is  42125.92199562963
# The cost function is  42125.9144376054
# The cost function is  42125.90690680473
# The cost function is  42125.89940312958
# The cost function is  42125.89192648223
# The cost function is  42125.884476765335
# The cost function is  42125.877053881886
# The cost function is  42125.86965773524
# The cost function is  42125.86228822908
# The cost function is  42125.854945267456
# The cost function is  42125.84762875475
# The cost function is  42125.84033859573
# The cost function is  42125.833074695416
# The cost function is  42125.825836959266
# The cost function is  42125.81862529301
# The cost function is  42125.81143960277
# The cost function is  42125.80427979496
# The cost function is  42125.79714577638
# The cost function is  42125.79003745411
# The cost function is  42125.78295473561
# The cost function is  42125.77589752866
# The cost function is  42125.76886574136
# The cost function is  42125.761859282145
# The cost function is  42125.75487805979
# The cost function is  42125.7479219834
# The cost function is  42125.740990962404
# The cost function is  42125.73408490654
# The cost function is  42125.72720372589
# The cost function is  42125.720347330855
# The cost function is  42125.71351563215
# The cost function is  42125.70670854085
# The cost function is  42125.699925968285
# The cost function is  42125.69316782615
# The cost function is  42125.686434026466
# The cost function is  42125.67972448153
# The cost function is  42125.673039104004
# The cost function is  42125.6663778068
# The cost function is  42125.65974050322
# The cost function is  42125.65312710682
# The cost function is  42125.646537531495
# The cost function is  42125.63997169144
# The cost function is  42125.63342950116
# The cost function is  42125.62691087547
# The cost function is  42125.62041572949
# The cost function is  42125.61394397866
# The cost function is  42125.607495538694
# The cost function is  42125.60107032565
# The cost function is  42125.594668255835
# The cost function is  42125.58828924592
# The cost function is  42125.58193321283
# The cost function is  42125.5756000738
# The cost function is  42125.56928974637
# The cost function is  42125.563002148374
# The cost function is  42125.556737197934
# The cost function is  42125.5504948135
# The cost function is  42125.54427491377
# The cost function is  42125.538077417754
# The cost function is  42125.531902244766
# The cost function is  42125.5257493144
# The cost function is  42125.51961854653
# The cost function is  42125.51350986134
# The cost function is  42125.50742317926
# The cost function is  42125.501358421076
# The cost function is  42125.4953155078
# The cost function is  42125.48929436074
# The cost function is  42125.4832949015
# The cost function is  42125.47731705198
# The cost function is  42125.47136073433
# The cost function is  42125.46542587098
# The cost function is  42125.459512384674

# %%
cost_values
# Out:
# array([63390.22508396, 55810.363887  , 55523.96463893, ...,
#        42125.47136073, 42125.46542587, 42125.45951238])

# %%
# Now, lets see our trained weights
print('Our learned value of theta: ',theta.ravel())
# Out:
# Our learned value of theta:  [ 1.18864349 -3.85208068]

# %% [markdown]
# Lets visualize how or error reduced during the iteration. This is the power of gradient descent.

# %%
plt.plot(cost_values)
plt.ylabel('Cost J')
plt.xlabel('Iterations');

# %% [markdown]
# Notice that at the `1500th iteration`, the model doesnt really change anymore. You should actually stop the iteration at that time and save cost of processing

# %% [markdown]
# Lets see our regression line.
# Note: YOU DON'T NEED TO COUNT THE NUMBER OF DATA POINT THAT YOUR LINE SEPERATES; lol!

# %%
x_plot = np.arange(5,23)
y_plot = theta[0]*x_plot + theta[1]
# Plot gradient descent
plt.scatter(x[:,0], y, s=30, c='r', marker='o', linewidths=1)
plt.plot(x_plot,y_plot, label='Linear regression (Gradient descent)')

# %% [markdown]
# ### Prediction

# %% [markdown]
# Here, I hard coded the learned weights in the model that we defined earlier.
# ![Title](img/model.gif)

# %%
def predict():
    input_ = float(input("Input the population size/10000: "))
    print("For a population of ", input_, ", the profit is $", ((input_ * 1.18864349) - 3.85208068) * 10000)

# %%
predict()
# Out:
# Input the population size/10000: 5.5
# For a population of  5.5 , the profit is $ 26854.585150000003

# %% [markdown]
# We could even find our input based if we have the output, although it is not realistic in this case

# %%
def predict_inverse():
    input_ = float(input("Input the Profit size: "))
    print("For a profit of ", input_, " the population is ", (((input_ / 10000) + 3.85208068) / 1.18864349)*10000 )

# %%
predict_inverse()
# Out:
# Input the Profit size: 26854.585150000003
# For a profit of  26854.585150000003  the population is  55000.0

# %% [markdown]
# ### Assignment:
#
# 1. Use `scikit-learn` to develop a linear regression model using the same dataset in this practice and compare result.
# 2. Explore the internet for an univariant dataset and use this algorithim to train a linear regression model. Use `scikit-learn` too
#
# Assignment is due for submission on `29/03/2019`.
#
# Summission link will be posted on the `WhatsApp Class Group`
