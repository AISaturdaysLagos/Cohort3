# %% [markdown]
# # AI Saturdays Lagos - 3rd Cohort - Week 1

# %% [markdown]
# ## Linear Algebra, Probability and Statistics, Calculus

# %% [markdown]
# > The topic, concepts and codes that we will explore are relevant for machine learning and deep learning. Please attempt all exercise.

# %% [markdown]
# ## Linear Algebra

# %% [markdown]
# **Importation of necessary libraries needed.**
# * pandas is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
# * NumPy is a module that supports vectors and matrices in an optimised way.
# * SciPy (pronounced “Sigh Pie”) is a Python-based ecosystem of open-source software for mathematics (including statistics, science, and engineering.

# %%
import numpy as np # Numpy (numerical arrays in Python)
import pandas as pd
import scipy

# %% [markdown]
# ### **Scalar Quantities**
# * A Scalar is just a single number usually represented in lowercase italics, * x*.
# * It has only magnitude
# * It is a 0-dimensional tensor
# * It can be integers, rational number, real numbers, natural numbers etc

# %%
scalar = 2
scalar

# %%
# Lets check if the about is a scalar variable
print(np.isscalar(scalar), type(scalar))

# %% [markdown]
# 1. Excercise:
#     - Test - [2]

# %% [markdown]
# ### **Vector Quantities**
# In machine learning, a vector is used to represent columns or row in a dataset. Each column(features) can denote particular features .
#
# > For example, consider column Age below that denotes the age of 4 users in our dataset.

# %%
# we can construct a vector from a python list
vector_list = [24, 16, 45, 50]
vector_list

# %%
# we can construct from a numpy arrays
vector_np = np.array([24, 16, 45, 50])
vector_np

# %%
# This will return the shape of the matrix
vector_np.shape

# %%
# With numpy, we easily change the dimension of the vector.
# With the function .reshape, the 1 x 4 matrix was changed to a 4 x 1 matrix
vector_reshaped = vector_np.reshape(4, 1)
vector_reshaped

# %% [markdown]
# #### ** Vector Addition **
# With numpy, we can add vectors to scalars and vectors with vectors easily.

# %%
A = vector_np
B = 32
A + B

# %%
A

# %%
vector_reshaped + B

# %%
# here, we can see the effect of of matrix multiplication (m x n . n x p = m x p)
mult = vector_reshaped * A
mult

# %% [markdown]
# ## **Class Exercise**
#
# > A = [21, 30, 18]
#
# > B = [14, 19, 1]
#
# > C = [2]
#
# > D = [12, 3]
#
# **SOLVE**
# - A + B
# - A * B
# - A - B
# - A + C
# - A * C
# - A + D
# - A * D
# - A * (B-reshaped)
# - A * (D-reshaped)
#
# > *hint: convert the list (A, B, C, D) to numpy arrays*

# %% [markdown]
# ### **Matrix Quantities**

# %% [markdown]
# > - A matrix is a 2-D array (2-D tensor) of numbers, symbols, expressions, arranged in rows and columns
# > - It is a A real-valued matrix has a height m and width n,
# > - It can be integers, rational number, real numbers, natural numbers etc

# %%
# 2 X 2 matrix
A_list = [[-1, 2],
     [4, 3]]
A_list

# %%
print(A_list[0][0])

# %%
B_list = [[-7, 4],
     [4, 0]]
B_list

# %%
# there is an error here because, unlike numpy, you can not multiply python list easily this way.
print(A_list * B_list)

# %%
A_np = np.matrix([[-1, 2],
              [4, 3]])
A_np

# %%
B_np = np.matrix([[-7, 4],
     [4, 0]])
B_np

# %% [markdown]
# **Class Exercise**
# > Create  any 3 x 3 matrix of your choice using list and numpy

# %% [markdown]
# **Adding two matricies**

# %%
sum_A_B = A_np * B_np
sum_A_B

# %% [markdown]
# **Class Excercise**
# > - Multiply matrix A and B
# > - Create two 3 x 3 matrix and +, -, x

# %% [markdown]
# ### **Solving a Matrix equation such as:**
# >  Let assume an equation * AX = B*
#
#  *A and B is a matrix*
#
# >  How do we find the value of X

# %%
A = np.matrix([[-1, 2],
              [4, 3]])

B = np.matrix([[-7, 4],
     [4, 0]])

# %% [markdown]
# find the inverse of A

# %%
A_inverse = np.linalg.inv(A_np)
A_inverse

# %%
# Multiply the Inverse by B to get X
X = A_inverse * B_np
X

# %% [markdown]
# > CLASS DISCUSSION
#
# What do you think happen there?

# %% [markdown]
# ** Using Scipy to compute **
#
# With scipy, you can make the computation much faster

# %%
X = np.linalg.solve(A_np, B_np)
X

# %% [markdown]
# **Finding the determinant of a matrix**

# %%
matrix = np.matrix([[-1, 2],
              [4, 3]])
det = np.linalg.det(matrix)
det

# %% [markdown]
# **Finding the Inverse of a Matrix**

# %%
matrix = np.matrix([[-1, 2],
              [4, 3]])
inverse = np.linalg.inv(matrix)
inverse

# %% [markdown]
# #### ** Finding the Transpose of Matrix**

# %%
# for a 2 x 2 matrix
transpose = np.transpose(matrix)
transpose

# %%
# for a 3 x 4 matrix

matrix = np.matrix([[1,5,3,6],
                   [2,9,3,0],
                   [5,2,8,6]])
print(np.transpose(matrix))

# %% [markdown]
# **Finding Eigenvalues**

# %%
matrix = np.matrix([[-1, 2],
              [4, 3]])
eigvals = np.linalg.eigvals(matrix)
print("The eigen values are", eigvals[0], " and ", eigvals[1])

# %% [markdown]
# Others functions you can explore

# %%
# This will return of ones matrix
x = np.ones((3,3))
x

# %%
# this will return a range of numbers 
x = np.arange(5) 
x

# %%
#This will return randoms number
y = np.random.rand(2, 2)
y

# %% [markdown]
# Lets Try Something Interesting with images

# %%
import scipy.misc

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = scipy.misc.imread("../input/images/ladiKwali.jpg")
img2 = plt.imread("../input/images/ladiKwali.jpg")

# %%
# do you know this woman? Read about Ladi Kwali
plt.imshow(img2)

# %%
#the image ia actually a tensor consisting of pixel values. 
#this is waht makes computer vision possible
img.shape

# %%
 img

# %% [markdown]
# ## Statistics

# %% [markdown]
# ### **Statistics**

# %% [markdown]
# A large number of methods collectively compute descriptive statistics and other related operations on DataFrame.
#
# Most of these are aggregations like sum(), mean(), but some of them, like sumsum(), produce an object of the same size.
#
# Generally speaking, these methods take an axis argument, just like ndarray.{sum, std, ...}, but the axis can be specified by name or integer
#
# > **Lets generate data using dictionaries**

# %%
# import pandas as pd
# import numpy as np

#Create a Dictionary of series
d = {'Name':pd.Series(['Teju','Stanley','George','Bisi','Francis','Okoro','Abebe',
   'Tola','Fela','Udeme','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])}

#Create a DataFrame
df = pd.DataFrame(d)
df

#OR

# dd = {'Name':['Teju','Stanley','George','Bisi','Francis','Okoro','Abebe',
#    'Tola','Fela','Udeme','Betina','Andres'],
#    'Age':[25,26,25,23,30,29,23,34,40,30,51,46],
#    'Rating':[4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65]}

# dff = pd.DataFrame(dd, columns= ['Name', 'Age', 'Rating'])
# dff

# %%
df.to_csv(r'class.csv')

# %%
df.head()

# %% [markdown]
# ** importing an external dataset **

# %%
# dff = pd.read_csv('class.csv')
# dff

# %% [markdown]
# ### **sum()**
# Returns the sum of the values for the requested axis. By default, axis is index (axis=0).

# %%
print (df.sum())

# %% [markdown]
# ### **mean()**
# Returns the average value

# %%
print (df.mean())

# %% [markdown]
# ### **std()**
# Returns the Bressel standard deviation of the numerical columns.

# %%
print (df.std())

# %% [markdown]
# **Other Functions & Description**
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Summarizing Data**
# The describe() function computes a summary of statistics pertaining to the DataFrame columns.

# %%
print (df.describe())

# %%
print (df. describe(include='all'))

# %% [markdown]
# ### Plotting

# %%
df.groupby('Name')['Age'].first().plot.bar()

# %%
df.groupby('Name')['Age'].first().plot.pie()

# %% [markdown]
# ## **Calculus**

# %% [markdown]
# You need to know some basic calculus in order to understand how functions change over time (derivatives), and to calculate the total amount of a quantity that accumulates over a time period (integrals). The language of calculus will allow you to speak precisely about the properties of functions and better understand their behaviour.
#
# Normally taking a calculus course involves doing lots of tedious calculations by hand, but having the power of computers on your side can make the process much more fun. This section describes the key ideas of calculus which you’ll need to know to understand machine learning concepts.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Formula Method as described in the above picture**

# %%
def xPwr(x, pwr):
    return x ** pwr

def getDeriv(func, x, n):
    h = 0.0001
    return (func(x+h, n) - func(x, n))/h

# %%
x = 3
power = 2
derivative = getDeriv(xPwr, x, power)

# %%
derivative

# %%
def actual(x, n):
    power = n-1
    var = n * x
    return print(var**power)

# %%
actual = actual(3, 2)
actual

# %%
from sympy import *
x, y, z = symbols('x y, z')
init_printing(use_unicode=True)

# %% [markdown]
# ## **Derivatives**

# %% [markdown]
# To take derivatives, use the diff function.

# %%
print(diff(cos(x), x)) #the stand-alone-'x' means the variable should be differentiated once

# %%
print(diff(exp(x**2), x))

# %% [markdown]
# diff can take multiple derivatives at once. To take multiple derivatives, pass the variable as many times as you wish to differentiate, or pass a number after the variable. For example, both of the following find the third derivative of x4.

# %%
print(diff(x**4, x, x, x))

# %%
print(diff(x**4, x, 3))
